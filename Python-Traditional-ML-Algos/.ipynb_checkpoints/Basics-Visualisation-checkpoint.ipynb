# %% [markdown]
# **This Notebook contains the following examples** <br>
# > &#9673; scatter plots with colorbar() <br>
# > &#9673; plot stacked/ overlapping areas <br>
# > &#9673; create tabular correlation matrix <br>
# > &#9673; aligned columns or rows of subplots (with spacing) <br>
# > &#9673; sharing axes values across plots <br>
# > &#9673; create some normally distributed data <br>
# > &#9673; plt.GridSpec(): complicated plot arangements <br>

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000*rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.4,
            cmap='viridis')
plt.colorbar();  # show color scale

# %%
#http://pandas-docs.github.io/pandas-docs-travis/visualization.html#visualization-scatter-matrix
df = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df.plot.area()
df.plot.area(stacked=False);

# %%
# create tabular correlation matrix
#https://www.learndatasci.com/tutorials/data-science-statistics-using-python/
''' The values in the correlation matrix table will be between -1 and 1 (see below).
A value of -1 indicates the strongest possible negative correlation, meaning as one 
variable decreases the other increases. And a value of 1 indicates the opposite. 
'''
data = pd.read_csv("Datasets/titanic-train.csv", index_col='PassengerId') 

import seaborn as sns
sns.set_style('darkgrid')
sns.set(font_scale=1.5)

corr = data.corr()
corrGraph, ax = plt.subplots(figsize=(8,5)) 

# graph correlation matrix
corrGraph = sns.heatmap(corr, ax=ax,
                xticklabels=corr.columns.values,
                yticklabels=corr.columns.values,
                cmap='coolwarm')

# %%
#Aligned columns or rows of subplots (with spacing)
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %%
#Sharing axes values across plots
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %%
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
#plt.GridSpec(): complicated plot arangementsplt.subplot(grid[0, 0])

grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)
plt.subplot(grid[0, 0])
plt.subplot(grid[0, 1:])
plt.subplot(grid[1, :2])
plt.subplot(grid[1, 2]);
